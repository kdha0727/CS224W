# %% [markdown]
# # Install and import torch-geometric

# %%
import torch

CUDA_AVAILABLE = torch.cuda.is_available()

try:
    import torch_geometric

except ImportError as import_exc:  # Pip Installation via pure python code

    import sys
    import subprocess

    TORCH = torch.__version__.split('+')[0]
    CUDA = 'cu' + torch.version.cuda.replace('.', '') if CUDA_AVAILABLE else 'cpu'

    try:
        subprocess.run([
            sys.executable, '-m', 'pip', 'install',
            f'torch-scatter==latest+{CUDA}',
            f'torch-sparse==latest+{CUDA}',
            f'torch-cluster==latest+{CUDA}',
            f'torch-spline-conv==latest+{CUDA}',
            f'torch-geometric',
            '-f', f'https://pytorch-geometric.com/whl/torch-{TORCH}.html'
        ], check=True)

    # check=True will raise CalledProcessError after unsuccessful installation
    except subprocess.CalledProcessError as proc_exc:
        raise import_exc from proc_exc

import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.utils import accuracy, add_self_loops, to_dense_adj
import torch_geometric.nn as gnn
import torch_geometric.transforms as T

import os
import glob

device = torch.device('cuda' if CUDA_AVAILABLE else 'cpu')

# %% [markdown]
# # Load and preprocess data

# %%
# load Cora dataset
dataset = Planetoid(root='./datasets/Cora', name='Cora')
data = dataset[0].to(device)

in_dim = dataset.num_node_features
class_cardinality = dataset.num_classes
node_features = data.x
A = data.edge_index

# split dataset
train_node = data.train_mask
train_target = data.y[data.train_mask]
valid_node = data.val_mask
valid_target = data.y[data.val_mask]
test_node = data.test_mask
test_target = data.y[data.test_mask]

# %%
A = to_dense_adj(A).squeeze(0)
self_loop = torch.eye(*A.shape).to(A)
A += self_loop  # add self-loops

deg = A.sum(1)
deg_inv = deg.pow(-0.5)
deg_inv.masked_fill_(deg_inv == torch.inf, 0.)
deg_inv = deg_inv * self_loop

A = deg_inv.mm(A).mm(deg_inv)
A
# Out:
# tensor([[0.2500, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.2500, 0.2041,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.2041, 0.1666,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.4999, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.2000, 0.2000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.2000, 0.2000]],
#        device='cuda:0')

# %% [markdown]
# # Implement GAT model

# %%
class GATLayer(nn.Module):

    def __init__(self, in_features, out_features, dropout, alpha, concat=True):

        super().__init__()

        self.in_features = in_features
        self.out_features = out_features
        self.alpha = alpha
        self.concat = concat
        self.dropout = dropout

        self.W = nn.Parameter(torch.zeros(in_features, out_features))
        self.a = nn.Parameter(torch.zeros(2 * out_features, 1))

        self.leaky_relu = nn.LeakyReLU(alpha)
        self.dropout = nn.Dropout(dropout)

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.W, gain=1.414)
        nn.init.xavier_uniform_(self.a, gain=1.414)

    def forward(self, x, adj):

        h = torch.mm(x, self.W)
        N = h.shape[0]
        a_input = torch.cat([h.repeat(1, N).view(N * N, -1), h.repeat(N, 1)], dim=1).view(N, -1, 2 * self.out_features)
        e = torch.matmul(a_input, self.a).squeeze(2)
        e = self.leaky_relu(e)

        zero_vec = -9e15 * torch.ones_like(e)
        attention = torch.where(adj > 0, e, zero_vec)
        attention = attention.softmax(dim=1)
        attention = self.dropout(attention)
        h_prime = torch.matmul(attention, h)
        if self.concat:
            return F.elu(h_prime)
        else:
            return h_prime

# %%
class GNNNet(nn.Module):

    def __init__(self, nfeat, nhid, nheads, nclass, dropout, alpha=0.2):
        super().__init__()
        self.layer1_heads = nn.ModuleList([
            GATLayer(nfeat, nhid, dropout=dropout, alpha=alpha, concat=True)
            for _ in range(nheads)
        ])
        self.layer2 = GATLayer(nhid * nheads, nclass, dropout=dropout, alpha=alpha, concat=False)
        self.dropout = nn.Dropout(dropout)
        self.elu = nn.ELU()

    def forward(self, x, adj):
        x = self.dropout(x)
        x = torch.cat([head(x, adj) for head in self.layer1_heads], dim=1)
        x = self.dropout(x)
        x = self.layer2(x, adj)
        x = self.elu(x)
        return x.log_softmax(dim=1)

# %%
# Another Implementation with Torch Geometric

class GATNet(nn.Module):

    def __init__(self, nfeat, nhid, num_head, nclass, dropout):
        super().__init__()
        self.layer0 = gnn.GATConv(nfeat, nhid, heads=num_head, concat=True, dropout=dropout)
        self.layer1 = gnn.GATConv(nhid * num_head, nclass, concat=False, dropout=dropout)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()

    def forward(self, x, adj):
        x = self.dropout(x)
        x = self.layer0(x, adj)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.layer1(x, adj)
        return x.log_softmax(dim=1)

# %%
hidden_dim = 32  # We set the number of hid. dim as 8 for running on Colab!
dropout_rate = 0.75
lr = 5e-3
weight_decay = 5e-4
epochs = 10000
patience = 200
num_head = 16  # We set the number of heads as 1 for running on Colab!

# %%
loss_values = []
bad_counter = 0
best = epochs + 1
best_epoch = 0

model = GNNNet(in_dim, hidden_dim, num_head, class_cardinality, dropout_rate).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

# %%
def step(epoch):

    log = "[Epoch] {:0>3} ".format(epoch)

    model.train().zero_grad()

    log_logits = model(node_features, A)
    train_loss = F.nll_loss(log_logits[train_node], train_target)
    train_acc = accuracy(log_logits[train_node].argmax(1), train_target)

    train_loss.backward()
    optimizer.step()

    log += " [Train] Loss: {:6.4f}, Accuracy: {:6.4f}".format(train_loss, train_acc)

    model.eval()

    with torch.no_grad():
        log_logits = model(node_features, A)
        valid_loss = F.nll_loss(log_logits[valid_node], valid_target)
        valid_acc = accuracy(log_logits[valid_node].argmax(1), valid_target)

    log += " [Valid] Loss: {:6.4f}, Accuracy: {:6.4f}".format(valid_loss, valid_acc)
    print(log)

    return valid_loss.item()


@torch.no_grad()
def compute_test():

    model.eval()

    log_logits = model(node_features, A)
    test_loss = F.nll_loss(log_logits[valid_node], valid_target)
    test_acc = accuracy(log_logits[valid_node].argmax(1), valid_target)

    return test_loss.item(), test_acc

# %%
try:

    for e in range(epochs):
        loss_values.append(step(e))
        torch.save(model.state_dict(), "%s.pth" % e)
        if loss_values[-1] < best:
            best = loss_values[-1]
            best_epoch = e
            bad_counter = 0
        else:
            bad_counter += 1
        if bad_counter == patience:
            break

    print("Optimization Finished!\nLoading %sth model\n" % best_epoch)
    model.load_state_dict(torch.load("%s.pth" % best_epoch))

    best_test_loss, best_test_acc = compute_test()
    print("[Test] Loss: {:6.4f}, Accuracy: {:6.4f}".format(best_test_loss, best_test_acc))

finally:
    for file in glob.iglob('*.pth'):
        os.remove(file)
# Out:
# [Epoch] 000  [Train] Loss: 2.7472, Accuracy: 0.1786 [Valid] Loss: 1.9477, Accuracy: 0.1880
# [Epoch] 001  [Train] Loss: 2.7749, Accuracy: 0.1500 [Valid] Loss: 1.9002, Accuracy: 0.2420
# [Epoch] 002  [Train] Loss: 2.8936, Accuracy: 0.1143 [Valid] Loss: 1.8551, Accuracy: 0.2980
# [Epoch] 003  [Train] Loss: 2.4070, Accuracy: 0.1857 [Valid] Loss: 1.8171, Accuracy: 0.3600
# [Epoch] 004  [Train] Loss: 2.1712, Accuracy: 0.2214 [Valid] Loss: 1.7843, Accuracy: 0.3880
# [Epoch] 005  [Train] Loss: 2.4434, Accuracy: 0.2214 [Valid] Loss: 1.7535, Accuracy: 0.4380
# [Epoch] 006  [Train] Loss: 2.3732, Accuracy: 0.2214 [Valid] Loss: 1.7272, Accuracy: 0.4680
# [Epoch] 007  [Train] Loss: 2.0766, Accuracy: 0.3000 [Valid] Loss: 1.7061, Accuracy: 0.4760
# [Epoch] 008  [Train] Loss: 2.5431, Accuracy: 0.2286 [Valid] Loss: 1.6873, Accuracy: 0.4860
# [Epoch] 009  [Train] Loss: 2.3309, Accuracy: 0.2643 [Valid] Loss: 1.6718, Accuracy: 0.4920
# [Epoch] 010  [Train] Loss: 2.1841, Accuracy: 0.2357 [Valid] Loss: 1.6590, Accuracy: 0.5140
# [Epoch] 011  [Train] Loss: 2.0772, Accuracy: 0.2643 [Valid] Loss: 1.6469, Accuracy: 0.5420
# [Epoch] 012  [Train] Loss: 2.1012, Accuracy: 0.2714 [Valid] Loss: 1.6359, Accuracy: 0.5600
# [Epoch] 013  [Train] Loss: 1.9730, Accuracy: 0.3357 [Valid] Loss: 1.6268, Accuracy: 0.5880
# [Epoch] 014  [Train] Loss: 1.9876, Accuracy: 0.3429 [Valid] Loss: 1.6172, Accuracy: 0.6060
# [Epoch] 015  [Train] Loss: 2.0162, Accuracy: 0.3143 [Valid] Loss: 1.6093, Accuracy: 0.6200
# [Epoch] 016  [Train] Loss: 1.9313, Accuracy: 0.3286 [Valid] Loss: 1.6003, Accuracy: 0.6420
# [Epoch] 017  [Train] Loss: 1.9100, Accuracy: 0.3143 [Valid] Loss: 1.5913, Accuracy: 0.6440
# [Epoch] 018  [Train] Loss: 2.0215, Accuracy: 0.3286 [Valid] Loss: 1.5828, Accuracy: 0.6600
# [Epoch] 019  [Train] Loss: 1.7474, Accuracy: 0.4000 [Valid] Loss: 1.5731, Accuracy: 0.6740
# [Epoch] 020  [Train] Loss: 1.8941, Accuracy: 0.3929 [Valid] Loss: 1.5619, Accuracy: 0.6840
# [Epoch] 021  [Train] Loss: 1.7682, Accuracy: 0.3571 [Valid] Loss: 1.5516, Accuracy: 0.6940
# [Epoch] 022  [Train] Loss: 1.7877, Accuracy: 0.4071 [Valid] Loss: 1.5401, Accuracy: 0.6980
# [Epoch] 023  [Train] Loss: 1.7645, Accuracy: 0.3643 [Valid] Loss: 1.5267, Accuracy: 0.7160
# [Epoch] 024  [Train] Loss: 1.6651, Accuracy: 0.3786 [Valid] Loss: 1.5129, Accuracy: 0.7220
# [Epoch] 025  [Train] Loss: 1.7935, Accuracy: 0.3500 [Valid] Loss: 1.4987, Accuracy: 0.7280
# [Epoch] 026  [Train] Loss: 1.6444, Accuracy: 0.3786 [Valid] Loss: 1.4802, Accuracy: 0.7320
# [Epoch] 027  [Train] Loss: 1.7114, Accuracy: 0.4071 [Valid] Loss: 1.4597, Accuracy: 0.7440
# [Epoch] 028  [Train] Loss: 1.6372, Accuracy: 0.4786 [Valid] Loss: 1.4409, Accuracy: 0.7520
# [Epoch] 029  [Train] Loss: 1.6827, Accuracy: 0.4857 [Valid] Loss: 1.4205, Accuracy: 0.7480
# [Epoch] 030  [Train] Loss: 1.7435, Accuracy: 0.4286 [Valid] Loss: 1.3997, Accuracy: 0.7540
# [Epoch] 031  [Train] Loss: 1.7284, Accuracy: 0.4286 [Valid] Loss: 1.3780, Accuracy: 0.7620
# [Epoch] 032  [Train] Loss: 1.4643, Accuracy: 0.5000 [Valid] Loss: 1.3547, Accuracy: 0.7620
# [Epoch] 033  [Train] Loss: 1.5038, Accuracy: 0.4714 [Valid] Loss: 1.3308, Accuracy: 0.7720
# [Epoch] 034  [Train] Loss: 1.6337, Accuracy: 0.4000 [Valid] Loss: 1.3072, Accuracy: 0.7780
# [Epoch] 035  [Train] Loss: 1.6081, Accuracy: 0.4500 [Valid] Loss: 1.2841, Accuracy: 0.7740
# [Epoch] 036  [Train] Loss: 1.6481, Accuracy: 0.3857 [Valid] Loss: 1.2607, Accuracy: 0.7820
# [Epoch] 037  [Train] Loss: 1.6548, Accuracy: 0.4071 [Valid] Loss: 1.2376, Accuracy: 0.7800
# [Epoch] 038  [Train] Loss: 1.4649, Accuracy: 0.4714 [Valid] Loss: 1.2150, Accuracy: 0.7780
# [Epoch] 039  [Train] Loss: 1.5879, Accuracy: 0.4143 [Valid] Loss: 1.1926, Accuracy: 0.7840
# [Epoch] 040  [Train] Loss: 1.7724, Accuracy: 0.4214 [Valid] Loss: 1.1731, Accuracy: 0.7780
# [Epoch] 041  [Train] Loss: 1.4638, Accuracy: 0.4429 [Valid] Loss: 1.1541, Accuracy: 0.7740
# [Epoch] 042  [Train] Loss: 1.5026, Accuracy: 0.4643 [Valid] Loss: 1.1356, Accuracy: 0.7760
# [Epoch] 043  [Train] Loss: 1.7214, Accuracy: 0.4571 [Valid] Loss: 1.1193, Accuracy: 0.7820
# [Epoch] 044  [Train] Loss: 1.4290, Accuracy: 0.4643 [Valid] Loss: 1.1033, Accuracy: 0.7840
# [Epoch] 045  [Train] Loss: 1.3725, Accuracy: 0.5071 [Valid] Loss: 1.0872, Accuracy: 0.7880
# [Epoch] 046  [Train] Loss: 1.3941, Accuracy: 0.5286 [Valid] Loss: 1.0700, Accuracy: 0.7880
# [Epoch] 047  [Train] Loss: 1.5430, Accuracy: 0.4643 [Valid] Loss: 1.0534, Accuracy: 0.7880
# [Epoch] 048  [Train] Loss: 1.3443, Accuracy: 0.5000 [Valid] Loss: 1.0373, Accuracy: 0.7900
# [Epoch] 049  [Train] Loss: 1.3423, Accuracy: 0.4857 [Valid] Loss: 1.0226, Accuracy: 0.7880
# [Epoch] 050  [Train] Loss: 1.4443, Accuracy: 0.5214 [Valid] Loss: 1.0081, Accuracy: 0.7920
# [Epoch] 051  [Train] Loss: 1.4051, Accuracy: 0.5714 [Valid] Loss: 0.9934, Accuracy: 0.7880
# [Epoch] 052  [Train] Loss: 1.4269, Accuracy: 0.4929 [Valid] Loss: 0.9818, Accuracy: 0.7860
# [Epoch] 053  [Train] Loss: 1.4219, Accuracy: 0.4786 [Valid] Loss: 0.9712, Accuracy: 0.7880
# [Epoch] 054  [Train] Loss: 1.3472, Accuracy: 0.5929 [Valid] Loss: 0.9608, Accuracy: 0.7880
# [Epoch] 055  [Train] Loss: 1.5284, Accuracy: 0.5143 [Valid] Loss: 0.9507, Accuracy: 0.7880
# [Epoch] 056  [Train] Loss: 1.1774, Accuracy: 0.5786 [Valid] Loss: 0.9413, Accuracy: 0.7940
# [Epoch] 057  [Train] Loss: 1.1818, Accuracy: 0.5929 [Valid] Loss: 0.9320, Accuracy: 0.7900
# [Epoch] 058  [Train] Loss: 1.2619, Accuracy: 0.4786 [Valid] Loss: 0.9233, Accuracy: 0.7920
# [Epoch] 059  [Train] Loss: 1.3698, Accuracy: 0.5500 [Valid] Loss: 0.9143, Accuracy: 0.7900
# [Epoch] 060  [Train] Loss: 1.3744, Accuracy: 0.5071 [Valid] Loss: 0.9058, Accuracy: 0.7900
# [Epoch] 061  [Train] Loss: 1.2912, Accuracy: 0.5500 [Valid] Loss: 0.8976, Accuracy: 0.7880
# [Epoch] 062  [Train] Loss: 1.2933, Accuracy: 0.5786 [Valid] Loss: 0.8899, Accuracy: 0.7880
# [Epoch] 063  [Train] Loss: 1.3337, Accuracy: 0.5429 [Valid] Loss: 0.8829, Accuracy: 0.7800
# [Epoch] 064  [Train] Loss: 1.3653, Accuracy: 0.5929 [Valid] Loss: 0.8754, Accuracy: 0.7780
# [Epoch] 065  [Train] Loss: 1.4043, Accuracy: 0.5786 [Valid] Loss: 0.8682, Accuracy: 0.7760
# [Epoch] 066  [Train] Loss: 1.1301, Accuracy: 0.6357 [Valid] Loss: 0.8607, Accuracy: 0.7780
# [Epoch] 067  [Train] Loss: 1.3618, Accuracy: 0.5357 [Valid] Loss: 0.8531, Accuracy: 0.7840
# [Epoch] 068  [Train] Loss: 1.5126, Accuracy: 0.4857 [Valid] Loss: 0.8458, Accuracy: 0.7840
# [Epoch] 069  [Train] Loss: 1.2724, Accuracy: 0.5500 [Valid] Loss: 0.8389, Accuracy: 0.7840
# [Epoch] 070  [Train] Loss: 1.2760, Accuracy: 0.5500 [Valid] Loss: 0.8318, Accuracy: 0.7820
# [Epoch] 071  [Train] Loss: 1.3192, Accuracy: 0.5000 [Valid] Loss: 0.8262, Accuracy: 0.7860
# [Epoch] 072  [Train] Loss: 1.2189, Accuracy: 0.5357 [Valid] Loss: 0.8213, Accuracy: 0.7860
# [Epoch] 073  [Train] Loss: 1.2889, Accuracy: 0.5929 [Valid] Loss: 0.8173, Accuracy: 0.7840
# [Epoch] 074  [Train] Loss: 1.3091, Accuracy: 0.5429 [Valid] Loss: 0.8137, Accuracy: 0.7860
# [Epoch] 075  [Train] Loss: 1.2355, Accuracy: 0.5500 [Valid] Loss: 0.8102, Accuracy: 0.7920
# [Epoch] 076  [Train] Loss: 1.5022, Accuracy: 0.5714 [Valid] Loss: 0.8071, Accuracy: 0.7920
# [Epoch] 077  [Train] Loss: 1.5344, Accuracy: 0.5214 [Valid] Loss: 0.8035, Accuracy: 0.7940
# [Epoch] 078  [Train] Loss: 1.3502, Accuracy: 0.5500 [Valid] Loss: 0.8001, Accuracy: 0.7940
# [Epoch] 079  [Train] Loss: 1.2267, Accuracy: 0.5500 [Valid] Loss: 0.7972, Accuracy: 0.7960
# [Epoch] 080  [Train] Loss: 1.2615, Accuracy: 0.5643 [Valid] Loss: 0.7936, Accuracy: 0.7960
# [Epoch] 081  [Train] Loss: 1.1464, Accuracy: 0.5786 [Valid] Loss: 0.7902, Accuracy: 0.7980
# [Epoch] 082  [Train] Loss: 1.2048, Accuracy: 0.6071 [Valid] Loss: 0.7869, Accuracy: 0.8000
# [Epoch] 083  [Train] Loss: 1.2717, Accuracy: 0.4929 [Valid] Loss: 0.7853, Accuracy: 0.8000
# [Epoch] 084  [Train] Loss: 1.1444, Accuracy: 0.6143 [Valid] Loss: 0.7840, Accuracy: 0.8000
# [Epoch] 085  [Train] Loss: 1.2050, Accuracy: 0.5786 [Valid] Loss: 0.7823, Accuracy: 0.8020
# [Epoch] 086  [Train] Loss: 1.1284, Accuracy: 0.5929 [Valid] Loss: 0.7816, Accuracy: 0.8020
# [Epoch] 087  [Train] Loss: 1.1080, Accuracy: 0.5929 [Valid] Loss: 0.7814, Accuracy: 0.8000
# [Epoch] 088  [Train] Loss: 1.3692, Accuracy: 0.5714 [Valid] Loss: 0.7821, Accuracy: 0.8020
# [Epoch] 089  [Train] Loss: 1.0132, Accuracy: 0.6857 [Valid] Loss: 0.7833, Accuracy: 0.8060
# [Epoch] 090  [Train] Loss: 1.1084, Accuracy: 0.6571 [Valid] Loss: 0.7855, Accuracy: 0.8120
# [Epoch] 091  [Train] Loss: 1.3197, Accuracy: 0.5857 [Valid] Loss: 0.7872, Accuracy: 0.8100
# [Epoch] 092  [Train] Loss: 1.1349, Accuracy: 0.6286 [Valid] Loss: 0.7882, Accuracy: 0.8100
# [Epoch] 093  [Train] Loss: 1.2467, Accuracy: 0.5286 [Valid] Loss: 0.7890, Accuracy: 0.8080
# [Epoch] 094  [Train] Loss: 1.1351, Accuracy: 0.6000 [Valid] Loss: 0.7887, Accuracy: 0.8020
# [Epoch] 095  [Train] Loss: 1.2142, Accuracy: 0.5357 [Valid] Loss: 0.7891, Accuracy: 0.8020
# [Epoch] 096  [Train] Loss: 1.3033, Accuracy: 0.5357 [Valid] Loss: 0.7897, Accuracy: 0.8080
# [Epoch] 097  [Train] Loss: 1.1306, Accuracy: 0.6071 [Valid] Loss: 0.7896, Accuracy: 0.8020
# [Epoch] 098  [Train] Loss: 1.2063, Accuracy: 0.5429 [Valid] Loss: 0.7892, Accuracy: 0.8000
# [Epoch] 099  [Train] Loss: 1.0339, Accuracy: 0.6071 [Valid] Loss: 0.7859, Accuracy: 0.8000
# [Epoch] 100  [Train] Loss: 1.0271, Accuracy: 0.6714 [Valid] Loss: 0.7812, Accuracy: 0.8000
# [Epoch] 101  [Train] Loss: 1.0943, Accuracy: 0.6357 [Valid] Loss: 0.7771, Accuracy: 0.8000
# [Epoch] 102  [Train] Loss: 1.1617, Accuracy: 0.5429 [Valid] Loss: 0.7732, Accuracy: 0.8040
# [Epoch] 103  [Train] Loss: 1.0851, Accuracy: 0.6214 [Valid] Loss: 0.7692, Accuracy: 0.8000
# [Epoch] 104  [Train] Loss: 0.9236, Accuracy: 0.6571 [Valid] Loss: 0.7657, Accuracy: 0.8020
# [Epoch] 105  [Train] Loss: 1.1917, Accuracy: 0.6143 [Valid] Loss: 0.7623, Accuracy: 0.8060
# [Epoch] 106  [Train] Loss: 1.1690, Accuracy: 0.5714 [Valid] Loss: 0.7586, Accuracy: 0.8060
# [Epoch] 107  [Train] Loss: 1.0847, Accuracy: 0.5429 [Valid] Loss: 0.7543, Accuracy: 0.8020
# [Epoch] 108  [Train] Loss: 1.1021, Accuracy: 0.6214 [Valid] Loss: 0.7510, Accuracy: 0.8020
# [Epoch] 109  [Train] Loss: 1.0309, Accuracy: 0.6143 [Valid] Loss: 0.7471, Accuracy: 0.8000
# [Epoch] 110  [Train] Loss: 1.1297, Accuracy: 0.6429 [Valid] Loss: 0.7433, Accuracy: 0.7980
# [Epoch] 111  [Train] Loss: 1.0906, Accuracy: 0.6571 [Valid] Loss: 0.7406, Accuracy: 0.7960
# [Epoch] 112  [Train] Loss: 1.0280, Accuracy: 0.6500 [Valid] Loss: 0.7371, Accuracy: 0.7960
# [Epoch] 113  [Train] Loss: 1.0291, Accuracy: 0.6214 [Valid] Loss: 0.7341, Accuracy: 0.7960
# [Epoch] 114  [Train] Loss: 1.0957, Accuracy: 0.6286 [Valid] Loss: 0.7312, Accuracy: 0.7980
# [Epoch] 115  [Train] Loss: 1.1478, Accuracy: 0.6071 [Valid] Loss: 0.7288, Accuracy: 0.7980
# [Epoch] 116  [Train] Loss: 0.8910, Accuracy: 0.7214 [Valid] Loss: 0.7262, Accuracy: 0.7960
# [Epoch] 117  [Train] Loss: 1.0289, Accuracy: 0.6286 [Valid] Loss: 0.7246, Accuracy: 0.7960
# [Epoch] 118  [Train] Loss: 1.0167, Accuracy: 0.6500 [Valid] Loss: 0.7242, Accuracy: 0.7960
# [Epoch] 119  [Train] Loss: 1.0954, Accuracy: 0.6500 [Valid] Loss: 0.7231, Accuracy: 0.7960
# [Epoch] 120  [Train] Loss: 1.1580, Accuracy: 0.5929 [Valid] Loss: 0.7229, Accuracy: 0.7980
# [Epoch] 121  [Train] Loss: 0.9053, Accuracy: 0.6571 [Valid] Loss: 0.7227, Accuracy: 0.7980
# [Epoch] 122  [Train] Loss: 1.1187, Accuracy: 0.6429 [Valid] Loss: 0.7220, Accuracy: 0.7980
# [Epoch] 123  [Train] Loss: 0.9281, Accuracy: 0.6286 [Valid] Loss: 0.7216, Accuracy: 0.7980
# [Epoch] 124  [Train] Loss: 0.9417, Accuracy: 0.6786 [Valid] Loss: 0.7215, Accuracy: 0.8000
# [Epoch] 125  [Train] Loss: 1.0006, Accuracy: 0.6286 [Valid] Loss: 0.7212, Accuracy: 0.8000
# [Epoch] 126  [Train] Loss: 1.0851, Accuracy: 0.5786 [Valid] Loss: 0.7209, Accuracy: 0.8020
# [Epoch] 127  [Train] Loss: 0.9925, Accuracy: 0.6857 [Valid] Loss: 0.7204, Accuracy: 0.8020
# [Epoch] 128  [Train] Loss: 1.0477, Accuracy: 0.5786 [Valid] Loss: 0.7207, Accuracy: 0.8020
# [Epoch] 129  [Train] Loss: 1.0012, Accuracy: 0.6143 [Valid] Loss: 0.7208, Accuracy: 0.8020
# [Epoch] 130  [Train] Loss: 0.9215, Accuracy: 0.7143 [Valid] Loss: 0.7206, Accuracy: 0.8000
# [Epoch] 131  [Train] Loss: 1.0071, Accuracy: 0.6214 [Valid] Loss: 0.7205, Accuracy: 0.8020
# [Epoch] 132  [Train] Loss: 0.9792, Accuracy: 0.6643 [Valid] Loss: 0.7207, Accuracy: 0.8020
# [Epoch] 133  [Train] Loss: 0.9643, Accuracy: 0.6286 [Valid] Loss: 0.7204, Accuracy: 0.8020
# [Epoch] 134  [Train] Loss: 0.9658, Accuracy: 0.6286 [Valid] Loss: 0.7195, Accuracy: 0.8020
# [Epoch] 135  [Train] Loss: 0.9950, Accuracy: 0.6143 [Valid] Loss: 0.7185, Accuracy: 0.8020
# [Epoch] 136  [Train] Loss: 1.1243, Accuracy: 0.6071 [Valid] Loss: 0.7181, Accuracy: 0.8020
# [Epoch] 137  [Train] Loss: 1.0074, Accuracy: 0.6071 [Valid] Loss: 0.7173, Accuracy: 0.8020
# [Epoch] 138  [Train] Loss: 1.1235, Accuracy: 0.6000 [Valid] Loss: 0.7161, Accuracy: 0.8060
# [Epoch] 139  [Train] Loss: 1.0240, Accuracy: 0.6214 [Valid] Loss: 0.7146, Accuracy: 0.8060
# [Epoch] 140  [Train] Loss: 0.9073, Accuracy: 0.6143 [Valid] Loss: 0.7136, Accuracy: 0.8060
# [Epoch] 141  [Train] Loss: 0.9060, Accuracy: 0.6429 [Valid] Loss: 0.7128, Accuracy: 0.8080
# [Epoch] 142  [Train] Loss: 0.9166, Accuracy: 0.6357 [Valid] Loss: 0.7117, Accuracy: 0.8060
# [Epoch] 143  [Train] Loss: 1.1264, Accuracy: 0.5714 [Valid] Loss: 0.7113, Accuracy: 0.8040
# [Epoch] 144  [Train] Loss: 0.9149, Accuracy: 0.6500 [Valid] Loss: 0.7108, Accuracy: 0.8040
# [Epoch] 145  [Train] Loss: 0.9774, Accuracy: 0.6286 [Valid] Loss: 0.7111, Accuracy: 0.8040
# [Epoch] 146  [Train] Loss: 1.0803, Accuracy: 0.6143 [Valid] Loss: 0.7121, Accuracy: 0.8040
# [Epoch] 147  [Train] Loss: 0.9593, Accuracy: 0.6500 [Valid] Loss: 0.7126, Accuracy: 0.8040
# [Epoch] 148  [Train] Loss: 0.8202, Accuracy: 0.6929 [Valid] Loss: 0.7136, Accuracy: 0.8000
# [Epoch] 149  [Train] Loss: 0.8357, Accuracy: 0.7000 [Valid] Loss: 0.7146, Accuracy: 0.7980
# [Epoch] 150  [Train] Loss: 0.9073, Accuracy: 0.6286 [Valid] Loss: 0.7153, Accuracy: 0.7980
# [Epoch] 151  [Train] Loss: 0.8440, Accuracy: 0.6500 [Valid] Loss: 0.7158, Accuracy: 0.8000
# [Epoch] 152  [Train] Loss: 0.9149, Accuracy: 0.6643 [Valid] Loss: 0.7165, Accuracy: 0.8000
# [Epoch] 153  [Train] Loss: 0.9029, Accuracy: 0.6500 [Valid] Loss: 0.7165, Accuracy: 0.8000
# [Epoch] 154  [Train] Loss: 0.9358, Accuracy: 0.6714 [Valid] Loss: 0.7179, Accuracy: 0.8000
# [Epoch] 155  [Train] Loss: 0.9755, Accuracy: 0.6357 [Valid] Loss: 0.7190, Accuracy: 0.7980
# [Epoch] 156  [Train] Loss: 0.9168, Accuracy: 0.6857 [Valid] Loss: 0.7216, Accuracy: 0.7980
# [Epoch] 157  [Train] Loss: 0.9250, Accuracy: 0.7143 [Valid] Loss: 0.7243, Accuracy: 0.7980
# [Epoch] 158  [Train] Loss: 0.9766, Accuracy: 0.6357 [Valid] Loss: 0.7263, Accuracy: 0.7960
# [Epoch] 159  [Train] Loss: 0.9450, Accuracy: 0.6357 [Valid] Loss: 0.7273, Accuracy: 0.7940
# [Epoch] 160  [Train] Loss: 0.9086, Accuracy: 0.6714 [Valid] Loss: 0.7282, Accuracy: 0.7960
# [Epoch] 161  [Train] Loss: 0.9124, Accuracy: 0.6714 [Valid] Loss: 0.7291, Accuracy: 0.7980
# [Epoch] 162  [Train] Loss: 0.9305, Accuracy: 0.6357 [Valid] Loss: 0.7292, Accuracy: 0.7960
# [Epoch] 163  [Train] Loss: 0.8298, Accuracy: 0.7071 [Valid] Loss: 0.7283, Accuracy: 0.7940
# [Epoch] 164  [Train] Loss: 0.9288, Accuracy: 0.6571 [Valid] Loss: 0.7265, Accuracy: 0.7940
# [Epoch] 165  [Train] Loss: 0.9009, Accuracy: 0.6643 [Valid] Loss: 0.7247, Accuracy: 0.7940
# [Epoch] 166  [Train] Loss: 0.9627, Accuracy: 0.6143 [Valid] Loss: 0.7229, Accuracy: 0.7940
# [Epoch] 167  [Train] Loss: 1.0046, Accuracy: 0.6357 [Valid] Loss: 0.7203, Accuracy: 0.7960
# [Epoch] 168  [Train] Loss: 0.8085, Accuracy: 0.7000 [Valid] Loss: 0.7178, Accuracy: 0.7960
# [Epoch] 169  [Train] Loss: 0.8998, Accuracy: 0.6571 [Valid] Loss: 0.7149, Accuracy: 0.7940
# [Epoch] 170  [Train] Loss: 1.1120, Accuracy: 0.5714 [Valid] Loss: 0.7128, Accuracy: 0.7940
# [Epoch] 171  [Train] Loss: 0.7821, Accuracy: 0.7214 [Valid] Loss: 0.7104, Accuracy: 0.7960
# [Epoch] 172  [Train] Loss: 0.9399, Accuracy: 0.6643 [Valid] Loss: 0.7081, Accuracy: 0.7980
# [Epoch] 173  [Train] Loss: 0.9502, Accuracy: 0.6286 [Valid] Loss: 0.7054, Accuracy: 0.7980
# [Epoch] 174  [Train] Loss: 0.9775, Accuracy: 0.6429 [Valid] Loss: 0.7038, Accuracy: 0.7980
# [Epoch] 175  [Train] Loss: 0.8668, Accuracy: 0.6429 [Valid] Loss: 0.7026, Accuracy: 0.7980
# [Epoch] 176  [Train] Loss: 0.8859, Accuracy: 0.6429 [Valid] Loss: 0.7007, Accuracy: 0.7980
# [Epoch] 177  [Train] Loss: 0.9435, Accuracy: 0.6143 [Valid] Loss: 0.6992, Accuracy: 0.7980
# [Epoch] 178  [Train] Loss: 0.9620, Accuracy: 0.6286 [Valid] Loss: 0.6978, Accuracy: 0.7980
# [Epoch] 179  [Train] Loss: 0.8105, Accuracy: 0.7071 [Valid] Loss: 0.6968, Accuracy: 0.7980
# [Epoch] 180  [Train] Loss: 0.9809, Accuracy: 0.6357 [Valid] Loss: 0.6962, Accuracy: 0.7960
# [Epoch] 181  [Train] Loss: 1.1169, Accuracy: 0.6071 [Valid] Loss: 0.6956, Accuracy: 0.7960
# [Epoch] 182  [Train] Loss: 0.9487, Accuracy: 0.6500 [Valid] Loss: 0.6953, Accuracy: 0.8020
# [Epoch] 183  [Train] Loss: 0.9692, Accuracy: 0.6000 [Valid] Loss: 0.6951, Accuracy: 0.8020
# [Epoch] 184  [Train] Loss: 0.9147, Accuracy: 0.6500 [Valid] Loss: 0.6947, Accuracy: 0.8020
# [Epoch] 185  [Train] Loss: 0.9585, Accuracy: 0.6786 [Valid] Loss: 0.6951, Accuracy: 0.8000
# [Epoch] 186  [Train] Loss: 0.9640, Accuracy: 0.6143 [Valid] Loss: 0.6943, Accuracy: 0.8000
# [Epoch] 187  [Train] Loss: 0.7784, Accuracy: 0.6857 [Valid] Loss: 0.6932, Accuracy: 0.8000
# [Epoch] 188  [Train] Loss: 1.0135, Accuracy: 0.6286 [Valid] Loss: 0.6930, Accuracy: 0.8000
# [Epoch] 189  [Train] Loss: 1.0258, Accuracy: 0.6143 [Valid] Loss: 0.6944, Accuracy: 0.7960
# [Epoch] 190  [Train] Loss: 1.0004, Accuracy: 0.6000 [Valid] Loss: 0.6961, Accuracy: 0.7940
# [Epoch] 191  [Train] Loss: 0.9052, Accuracy: 0.6643 [Valid] Loss: 0.6974, Accuracy: 0.7980
# [Epoch] 192  [Train] Loss: 0.8640, Accuracy: 0.6357 [Valid] Loss: 0.6976, Accuracy: 0.7980
# [Epoch] 193  [Train] Loss: 0.8306, Accuracy: 0.6929 [Valid] Loss: 0.6981, Accuracy: 0.7960
# [Epoch] 194  [Train] Loss: 0.9230, Accuracy: 0.6357 [Valid] Loss: 0.6982, Accuracy: 0.7960
# [Epoch] 195  [Train] Loss: 0.8569, Accuracy: 0.6357 [Valid] Loss: 0.6982, Accuracy: 0.7960
# [Epoch] 196  [Train] Loss: 0.7802, Accuracy: 0.6643 [Valid] Loss: 0.6986, Accuracy: 0.7960
# [Epoch] 197  [Train] Loss: 0.9426, Accuracy: 0.6429 [Valid] Loss: 0.6995, Accuracy: 0.8000
# [Epoch] 198  [Train] Loss: 1.0238, Accuracy: 0.6357 [Valid] Loss: 0.7000, Accuracy: 0.8000
# [Epoch] 199  [Train] Loss: 1.0105, Accuracy: 0.6857 [Valid] Loss: 0.6988, Accuracy: 0.8000
# [Epoch] 200  [Train] Loss: 0.8038, Accuracy: 0.6571 [Valid] Loss: 0.6989, Accuracy: 0.8000
# [Epoch] 201  [Train] Loss: 0.9074, Accuracy: 0.6500 [Valid] Loss: 0.6982, Accuracy: 0.7960
# [Epoch] 202  [Train] Loss: 0.8089, Accuracy: 0.7286 [Valid] Loss: 0.6963, Accuracy: 0.7960
# [Epoch] 203  [Train] Loss: 0.8804, Accuracy: 0.6286 [Valid] Loss: 0.6926, Accuracy: 0.7960
# [Epoch] 204  [Train] Loss: 1.0285, Accuracy: 0.6357 [Valid] Loss: 0.6893, Accuracy: 0.8000
# [Epoch] 205  [Train] Loss: 1.0108, Accuracy: 0.6143 [Valid] Loss: 0.6865, Accuracy: 0.7960
# [Epoch] 206  [Train] Loss: 0.9090, Accuracy: 0.6429 [Valid] Loss: 0.6841, Accuracy: 0.7940
# [Epoch] 207  [Train] Loss: 1.0031, Accuracy: 0.5571 [Valid] Loss: 0.6820, Accuracy: 0.7900
# [Epoch] 208  [Train] Loss: 0.8611, Accuracy: 0.6143 [Valid] Loss: 0.6805, Accuracy: 0.7900
# [Epoch] 209  [Train] Loss: 0.9553, Accuracy: 0.6286 [Valid] Loss: 0.6800, Accuracy: 0.7880
# [Epoch] 210  [Train] Loss: 0.9550, Accuracy: 0.6714 [Valid] Loss: 0.6791, Accuracy: 0.7900
# [Epoch] 211  [Train] Loss: 0.7278, Accuracy: 0.7071 [Valid] Loss: 0.6783, Accuracy: 0.7920
# [Epoch] 212  [Train] Loss: 0.8749, Accuracy: 0.6857 [Valid] Loss: 0.6774, Accuracy: 0.7920
# [Epoch] 213  [Train] Loss: 0.7173, Accuracy: 0.6929 [Valid] Loss: 0.6770, Accuracy: 0.7920
# [Epoch] 214  [Train] Loss: 0.9338, Accuracy: 0.6643 [Valid] Loss: 0.6768, Accuracy: 0.7900
# [Epoch] 215  [Train] Loss: 0.9729, Accuracy: 0.5714 [Valid] Loss: 0.6774, Accuracy: 0.7860
# [Epoch] 216  [Train] Loss: 0.8199, Accuracy: 0.6857 [Valid] Loss: 0.6775, Accuracy: 0.7860
# [Epoch] 217  [Train] Loss: 0.9288, Accuracy: 0.6714 [Valid] Loss: 0.6782, Accuracy: 0.7860
# [Epoch] 218  [Train] Loss: 0.9564, Accuracy: 0.6286 [Valid] Loss: 0.6790, Accuracy: 0.7880
# [Epoch] 219  [Train] Loss: 0.8330, Accuracy: 0.6929 [Valid] Loss: 0.6800, Accuracy: 0.7880
# [Epoch] 220  [Train] Loss: 0.8616, Accuracy: 0.6429 [Valid] Loss: 0.6810, Accuracy: 0.7920
# [Epoch] 221  [Train] Loss: 0.9070, Accuracy: 0.6357 [Valid] Loss: 0.6820, Accuracy: 0.7920
# [Epoch] 222  [Train] Loss: 0.9217, Accuracy: 0.6500 [Valid] Loss: 0.6832, Accuracy: 0.7860
# [Epoch] 223  [Train] Loss: 0.9534, Accuracy: 0.6357 [Valid] Loss: 0.6849, Accuracy: 0.7900
# [Epoch] 224  [Train] Loss: 0.9744, Accuracy: 0.6071 [Valid] Loss: 0.6858, Accuracy: 0.7880
# [Epoch] 225  [Train] Loss: 0.8602, Accuracy: 0.6714 [Valid] Loss: 0.6872, Accuracy: 0.7900
# [Epoch] 226  [Train] Loss: 0.9468, Accuracy: 0.6286 [Valid] Loss: 0.6888, Accuracy: 0.7880
# [Epoch] 227  [Train] Loss: 0.9425, Accuracy: 0.6786 [Valid] Loss: 0.6916, Accuracy: 0.7900
# [Epoch] 228  [Train] Loss: 1.0229, Accuracy: 0.6143 [Valid] Loss: 0.6951, Accuracy: 0.7880
# [Epoch] 229  [Train] Loss: 0.8843, Accuracy: 0.6643 [Valid] Loss: 0.6979, Accuracy: 0.7880
# [Epoch] 230  [Train] Loss: 0.9678, Accuracy: 0.6286 [Valid] Loss: 0.7014, Accuracy: 0.7940
# [Epoch] 231  [Train] Loss: 0.9560, Accuracy: 0.6214 [Valid] Loss: 0.7037, Accuracy: 0.7940
# [Epoch] 232  [Train] Loss: 0.9399, Accuracy: 0.6857 [Valid] Loss: 0.7048, Accuracy: 0.7940
# [Epoch] 233  [Train] Loss: 0.7318, Accuracy: 0.6786 [Valid] Loss: 0.7054, Accuracy: 0.7880
# [Epoch] 234  [Train] Loss: 0.9501, Accuracy: 0.6357 [Valid] Loss: 0.7060, Accuracy: 0.7880
# [Epoch] 235  [Train] Loss: 0.8976, Accuracy: 0.6500 [Valid] Loss: 0.7051, Accuracy: 0.7860
# [Epoch] 236  [Train] Loss: 0.8732, Accuracy: 0.7000 [Valid] Loss: 0.7048, Accuracy: 0.7860
# [Epoch] 237  [Train] Loss: 0.8683, Accuracy: 0.6786 [Valid] Loss: 0.7050, Accuracy: 0.7860
# [Epoch] 238  [Train] Loss: 0.9834, Accuracy: 0.6571 [Valid] Loss: 0.7060, Accuracy: 0.7860
# [Epoch] 239  [Train] Loss: 0.9377, Accuracy: 0.6357 [Valid] Loss: 0.7071, Accuracy: 0.7860
# [Epoch] 240  [Train] Loss: 0.9263, Accuracy: 0.6714 [Valid] Loss: 0.7070, Accuracy: 0.7860
# [Epoch] 241  [Train] Loss: 0.8973, Accuracy: 0.7071 [Valid] Loss: 0.7076, Accuracy: 0.7880
# [Epoch] 242  [Train] Loss: 0.9081, Accuracy: 0.6786 [Valid] Loss: 0.7079, Accuracy: 0.7880
# [Epoch] 243  [Train] Loss: 0.8022, Accuracy: 0.6929 [Valid] Loss: 0.7077, Accuracy: 0.7860
# [Epoch] 244  [Train] Loss: 0.7818, Accuracy: 0.6929 [Valid] Loss: 0.7070, Accuracy: 0.7840
# [Epoch] 245  [Train] Loss: 0.9848, Accuracy: 0.6143 [Valid] Loss: 0.7055, Accuracy: 0.7820
# [Epoch] 246  [Train] Loss: 0.9091, Accuracy: 0.6857 [Valid] Loss: 0.7048, Accuracy: 0.7840
# [Epoch] 247  [Train] Loss: 1.2101, Accuracy: 0.5286 [Valid] Loss: 0.7025, Accuracy: 0.7860
# [Epoch] 248  [Train] Loss: 0.9510, Accuracy: 0.6429 [Valid] Loss: 0.7012, Accuracy: 0.7920
# [Epoch] 249  [Train] Loss: 0.8214, Accuracy: 0.6786 [Valid] Loss: 0.7002, Accuracy: 0.7920
# [Epoch] 250  [Train] Loss: 0.8204, Accuracy: 0.7214 [Valid] Loss: 0.6996, Accuracy: 0.7920
# [Epoch] 251  [Train] Loss: 1.0557, Accuracy: 0.6000 [Valid] Loss: 0.6990, Accuracy: 0.7940
# [Epoch] 252  [Train] Loss: 0.8713, Accuracy: 0.6429 [Valid] Loss: 0.6983, Accuracy: 0.7920
# [Epoch] 253  [Train] Loss: 0.8103, Accuracy: 0.6857 [Valid] Loss: 0.6981, Accuracy: 0.7920
# [Epoch] 254  [Train] Loss: 0.9505, Accuracy: 0.6214 [Valid] Loss: 0.6990, Accuracy: 0.7940
# [Epoch] 255  [Train] Loss: 0.7870, Accuracy: 0.6714 [Valid] Loss: 0.7002, Accuracy: 0.7940
# [Epoch] 256  [Train] Loss: 0.7535, Accuracy: 0.7000 [Valid] Loss: 0.7006, Accuracy: 0.7960
# [Epoch] 257  [Train] Loss: 0.8876, Accuracy: 0.6500 [Valid] Loss: 0.7001, Accuracy: 0.7980
# [Epoch] 258  [Train] Loss: 0.9181, Accuracy: 0.6286 [Valid] Loss: 0.6995, Accuracy: 0.8000
# [Epoch] 259  [Train] Loss: 0.8720, Accuracy: 0.6857 [Valid] Loss: 0.6997, Accuracy: 0.8020
# [Epoch] 260  [Train] Loss: 0.8832, Accuracy: 0.6643 [Valid] Loss: 0.6999, Accuracy: 0.8000
# [Epoch] 261  [Train] Loss: 0.8558, Accuracy: 0.6643 [Valid] Loss: 0.7005, Accuracy: 0.8020
# [Epoch] 262  [Train] Loss: 0.9657, Accuracy: 0.6714 [Valid] Loss: 0.7011, Accuracy: 0.8000
# [Epoch] 263  [Train] Loss: 0.8146, Accuracy: 0.7000 [Valid] Loss: 0.7017, Accuracy: 0.7980
# [Epoch] 264  [Train] Loss: 0.9049, Accuracy: 0.5786 [Valid] Loss: 0.7022, Accuracy: 0.7960
# [Epoch] 265  [Train] Loss: 0.8971, Accuracy: 0.6357 [Valid] Loss: 0.7035, Accuracy: 0.7960
# [Epoch] 266  [Train] Loss: 0.8303, Accuracy: 0.6500 [Valid] Loss: 0.7050, Accuracy: 0.7940
# [Epoch] 267  [Train] Loss: 0.8491, Accuracy: 0.6714 [Valid] Loss: 0.7068, Accuracy: 0.7900
# [Epoch] 268  [Train] Loss: 1.0312, Accuracy: 0.6000 [Valid] Loss: 0.7081, Accuracy: 0.7860
# [Epoch] 269  [Train] Loss: 0.9628, Accuracy: 0.6643 [Valid] Loss: 0.7088, Accuracy: 0.7840
# [Epoch] 270  [Train] Loss: 0.9946, Accuracy: 0.5857 [Valid] Loss: 0.7098, Accuracy: 0.7820
# [Epoch] 271  [Train] Loss: 0.8662, Accuracy: 0.6500 [Valid] Loss: 0.7104, Accuracy: 0.7800
# [Epoch] 272  [Train] Loss: 0.9091, Accuracy: 0.6357 [Valid] Loss: 0.7112, Accuracy: 0.7840
# [Epoch] 273  [Train] Loss: 0.6809, Accuracy: 0.7071 [Valid] Loss: 0.7120, Accuracy: 0.7840
# [Epoch] 274  [Train] Loss: 0.8701, Accuracy: 0.7000 [Valid] Loss: 0.7135, Accuracy: 0.7800
# [Epoch] 275  [Train] Loss: 0.7962, Accuracy: 0.7071 [Valid] Loss: 0.7146, Accuracy: 0.7800
# [Epoch] 276  [Train] Loss: 0.8359, Accuracy: 0.6929 [Valid] Loss: 0.7143, Accuracy: 0.7840
# [Epoch] 277  [Train] Loss: 0.9252, Accuracy: 0.6357 [Valid] Loss: 0.7151, Accuracy: 0.7820
# [Epoch] 278  [Train] Loss: 1.0049, Accuracy: 0.6000 [Valid] Loss: 0.7162, Accuracy: 0.7800
# [Epoch] 279  [Train] Loss: 0.7708, Accuracy: 0.6929 [Valid] Loss: 0.7173, Accuracy: 0.7800
# [Epoch] 280  [Train] Loss: 0.8982, Accuracy: 0.6286 [Valid] Loss: 0.7186, Accuracy: 0.7800
# [Epoch] 281  [Train] Loss: 0.8875, Accuracy: 0.6500 [Valid] Loss: 0.7209, Accuracy: 0.7780
# [Epoch] 282  [Train] Loss: 0.8547, Accuracy: 0.6214 [Valid] Loss: 0.7249, Accuracy: 0.7780
# [Epoch] 283  [Train] Loss: 0.8168, Accuracy: 0.6500 [Valid] Loss: 0.7278, Accuracy: 0.7760
# [Epoch] 284  [Train] Loss: 0.9829, Accuracy: 0.6643 [Valid] Loss: 0.7299, Accuracy: 0.7760
# [Epoch] 285  [Train] Loss: 0.7548, Accuracy: 0.6929 [Valid] Loss: 0.7316, Accuracy: 0.7760
# [Epoch] 286  [Train] Loss: 0.8659, Accuracy: 0.6786 [Valid] Loss: 0.7329, Accuracy: 0.7800
# [Epoch] 287  [Train] Loss: 0.8663, Accuracy: 0.6857 [Valid] Loss: 0.7343, Accuracy: 0.7740
# [Epoch] 288  [Train] Loss: 0.7242, Accuracy: 0.7000 [Valid] Loss: 0.7343, Accuracy: 0.7740
# [Epoch] 289  [Train] Loss: 0.7578, Accuracy: 0.7000 [Valid] Loss: 0.7352, Accuracy: 0.7760
# [Epoch] 290  [Train] Loss: 0.7853, Accuracy: 0.7214 [Valid] Loss: 0.7378, Accuracy: 0.7720
# [Epoch] 291  [Train] Loss: 0.8232, Accuracy: 0.6643 [Valid] Loss: 0.7404, Accuracy: 0.7720
# [Epoch] 292  [Train] Loss: 0.8354, Accuracy: 0.6857 [Valid] Loss: 0.7432, Accuracy: 0.7700
# [Epoch] 293  [Train] Loss: 0.8708, Accuracy: 0.6714 [Valid] Loss: 0.7443, Accuracy: 0.7700
# [Epoch] 294  [Train] Loss: 0.7195, Accuracy: 0.7143 [Valid] Loss: 0.7433, Accuracy: 0.7700
# [Epoch] 295  [Train] Loss: 0.8156, Accuracy: 0.6500 [Valid] Loss: 0.7420, Accuracy: 0.7700
# [Epoch] 296  [Train] Loss: 0.7068, Accuracy: 0.7357 [Valid] Loss: 0.7415, Accuracy: 0.7700
# [Epoch] 297  [Train] Loss: 0.7867, Accuracy: 0.7000 [Valid] Loss: 0.7415, Accuracy: 0.7700
# [Epoch] 298  [Train] Loss: 0.9165, Accuracy: 0.6500 [Valid] Loss: 0.7423, Accuracy: 0.7700
# [Epoch] 299  [Train] Loss: 0.9994, Accuracy: 0.6500 [Valid] Loss: 0.7425, Accuracy: 0.7700
# [Epoch] 300  [Train] Loss: 0.8126, Accuracy: 0.6786 [Valid] Loss: 0.7424, Accuracy: 0.7720
# [Epoch] 301  [Train] Loss: 0.8443, Accuracy: 0.6857 [Valid] Loss: 0.7414, Accuracy: 0.7720
# [Epoch] 302  [Train] Loss: 1.0114, Accuracy: 0.6286 [Valid] Loss: 0.7407, Accuracy: 0.7780
# [Epoch] 303  [Train] Loss: 0.9090, Accuracy: 0.6500 [Valid] Loss: 0.7384, Accuracy: 0.7760
# [Epoch] 304  [Train] Loss: 0.8593, Accuracy: 0.6857 [Valid] Loss: 0.7358, Accuracy: 0.7760
# [Epoch] 305  [Train] Loss: 0.7233, Accuracy: 0.7429 [Valid] Loss: 0.7324, Accuracy: 0.7780
# [Epoch] 306  [Train] Loss: 0.9304, Accuracy: 0.6000 [Valid] Loss: 0.7279, Accuracy: 0.7780
# [Epoch] 307  [Train] Loss: 0.8916, Accuracy: 0.6429 [Valid] Loss: 0.7225, Accuracy: 0.7800
# [Epoch] 308  [Train] Loss: 0.8598, Accuracy: 0.6500 [Valid] Loss: 0.7172, Accuracy: 0.7860
# [Epoch] 309  [Train] Loss: 0.7431, Accuracy: 0.7214 [Valid] Loss: 0.7140, Accuracy: 0.7860
# [Epoch] 310  [Train] Loss: 0.7807, Accuracy: 0.7143 [Valid] Loss: 0.7124, Accuracy: 0.7880
# [Epoch] 311  [Train] Loss: 0.7871, Accuracy: 0.7071 [Valid] Loss: 0.7114, Accuracy: 0.7900
# [Epoch] 312  [Train] Loss: 0.7713, Accuracy: 0.6786 [Valid] Loss: 0.7103, Accuracy: 0.7880
# [Epoch] 313  [Train] Loss: 0.8919, Accuracy: 0.6857 [Valid] Loss: 0.7093, Accuracy: 0.7840
# [Epoch] 314  [Train] Loss: 0.9000, Accuracy: 0.6643 [Valid] Loss: 0.7094, Accuracy: 0.7860
# [Epoch] 315  [Train] Loss: 0.8131, Accuracy: 0.6929 [Valid] Loss: 0.7094, Accuracy: 0.7820
# [Epoch] 316  [Train] Loss: 0.8206, Accuracy: 0.6857 [Valid] Loss: 0.7098, Accuracy: 0.7820
# [Epoch] 317  [Train] Loss: 0.7173, Accuracy: 0.7071 [Valid] Loss: 0.7106, Accuracy: 0.7820
# [Epoch] 318  [Train] Loss: 0.8060, Accuracy: 0.6786 [Valid] Loss: 0.7119, Accuracy: 0.7800
# [Epoch] 319  [Train] Loss: 0.7262, Accuracy: 0.7357 [Valid] Loss: 0.7130, Accuracy: 0.7800
# [Epoch] 320  [Train] Loss: 0.7361, Accuracy: 0.7000 [Valid] Loss: 0.7146, Accuracy: 0.7780
# [Epoch] 321  [Train] Loss: 0.8130, Accuracy: 0.6571 [Valid] Loss: 0.7160, Accuracy: 0.7780
# [Epoch] 322  [Train] Loss: 0.8735, Accuracy: 0.6429 [Valid] Loss: 0.7184, Accuracy: 0.7780
# [Epoch] 323  [Train] Loss: 0.7808, Accuracy: 0.7071 [Valid] Loss: 0.7223, Accuracy: 0.7780
# [Epoch] 324  [Train] Loss: 0.7316, Accuracy: 0.7143 [Valid] Loss: 0.7273, Accuracy: 0.7740
# [Epoch] 325  [Train] Loss: 0.7867, Accuracy: 0.6786 [Valid] Loss: 0.7322, Accuracy: 0.7760
# [Epoch] 326  [Train] Loss: 0.8370, Accuracy: 0.7071 [Valid] Loss: 0.7365, Accuracy: 0.7760
# [Epoch] 327  [Train] Loss: 1.0225, Accuracy: 0.5643 [Valid] Loss: 0.7404, Accuracy: 0.7760
# [Epoch] 328  [Train] Loss: 0.7460, Accuracy: 0.6786 [Valid] Loss: 0.7433, Accuracy: 0.7760
# [Epoch] 329  [Train] Loss: 0.7514, Accuracy: 0.7071 [Valid] Loss: 0.7466, Accuracy: 0.7740
# [Epoch] 330  [Train] Loss: 0.9450, Accuracy: 0.6143 [Valid] Loss: 0.7487, Accuracy: 0.7680
# [Epoch] 331  [Train] Loss: 0.8356, Accuracy: 0.6786 [Valid] Loss: 0.7494, Accuracy: 0.7720
# [Epoch] 332  [Train] Loss: 0.8627, Accuracy: 0.6786 [Valid] Loss: 0.7499, Accuracy: 0.7720
# [Epoch] 333  [Train] Loss: 0.8185, Accuracy: 0.6857 [Valid] Loss: 0.7493, Accuracy: 0.7720
# [Epoch] 334  [Train] Loss: 0.8286, Accuracy: 0.7214 [Valid] Loss: 0.7491, Accuracy: 0.7720
# [Epoch] 335  [Train] Loss: 0.7856, Accuracy: 0.6786 [Valid] Loss: 0.7479, Accuracy: 0.7720
# [Epoch] 336  [Train] Loss: 0.7680, Accuracy: 0.6786 [Valid] Loss: 0.7458, Accuracy: 0.7720
# [Epoch] 337  [Train] Loss: 1.0326, Accuracy: 0.6500 [Valid] Loss: 0.7432, Accuracy: 0.7700
# [Epoch] 338  [Train] Loss: 0.8229, Accuracy: 0.6714 [Valid] Loss: 0.7409, Accuracy: 0.7720
# [Epoch] 339  [Train] Loss: 0.7738, Accuracy: 0.7000 [Valid] Loss: 0.7388, Accuracy: 0.7740
# [Epoch] 340  [Train] Loss: 0.9801, Accuracy: 0.6286 [Valid] Loss: 0.7370, Accuracy: 0.7740
# [Epoch] 341  [Train] Loss: 0.8034, Accuracy: 0.6786 [Valid] Loss: 0.7355, Accuracy: 0.7720
# [Epoch] 342  [Train] Loss: 0.8104, Accuracy: 0.6571 [Valid] Loss: 0.7345, Accuracy: 0.7700
# [Epoch] 343  [Train] Loss: 0.8183, Accuracy: 0.6929 [Valid] Loss: 0.7324, Accuracy: 0.7700
# [Epoch] 344  [Train] Loss: 0.8419, Accuracy: 0.6643 [Valid] Loss: 0.7298, Accuracy: 0.7720
# [Epoch] 345  [Train] Loss: 0.8402, Accuracy: 0.6929 [Valid] Loss: 0.7282, Accuracy: 0.7720
# [Epoch] 346  [Train] Loss: 0.8402, Accuracy: 0.6071 [Valid] Loss: 0.7267, Accuracy: 0.7720
# [Epoch] 347  [Train] Loss: 0.7859, Accuracy: 0.6929 [Valid] Loss: 0.7261, Accuracy: 0.7740
# [Epoch] 348  [Train] Loss: 0.7123, Accuracy: 0.7429 [Valid] Loss: 0.7254, Accuracy: 0.7740
# [Epoch] 349  [Train] Loss: 0.8434, Accuracy: 0.6643 [Valid] Loss: 0.7245, Accuracy: 0.7760
# [Epoch] 350  [Train] Loss: 0.9597, Accuracy: 0.6071 [Valid] Loss: 0.7240, Accuracy: 0.7740
# [Epoch] 351  [Train] Loss: 0.7947, Accuracy: 0.6786 [Valid] Loss: 0.7232, Accuracy: 0.7740
# [Epoch] 352  [Train] Loss: 0.8779, Accuracy: 0.6214 [Valid] Loss: 0.7233, Accuracy: 0.7740
# [Epoch] 353  [Train] Loss: 0.8144, Accuracy: 0.7000 [Valid] Loss: 0.7248, Accuracy: 0.7740
# [Epoch] 354  [Train] Loss: 0.8969, Accuracy: 0.6429 [Valid] Loss: 0.7271, Accuracy: 0.7720
# [Epoch] 355  [Train] Loss: 0.7364, Accuracy: 0.7214 [Valid] Loss: 0.7290, Accuracy: 0.7680
# [Epoch] 356  [Train] Loss: 0.8261, Accuracy: 0.6786 [Valid] Loss: 0.7306, Accuracy: 0.7720
# [Epoch] 357  [Train] Loss: 0.9813, Accuracy: 0.7000 [Valid] Loss: 0.7320, Accuracy: 0.7700
# [Epoch] 358  [Train] Loss: 0.8558, Accuracy: 0.6714 [Valid] Loss: 0.7347, Accuracy: 0.7720
# [Epoch] 359  [Train] Loss: 0.7100, Accuracy: 0.7214 [Valid] Loss: 0.7369, Accuracy: 0.7740
# [Epoch] 360  [Train] Loss: 0.7526, Accuracy: 0.6643 [Valid] Loss: 0.7385, Accuracy: 0.7740
# [Epoch] 361  [Train] Loss: 0.8462, Accuracy: 0.7000 [Valid] Loss: 0.7398, Accuracy: 0.7720
# [Epoch] 362  [Train] Loss: 0.6756, Accuracy: 0.7286 [Valid] Loss: 0.7406, Accuracy: 0.7700
# [Epoch] 363  [Train] Loss: 0.6596, Accuracy: 0.7571 [Valid] Loss: 0.7408, Accuracy: 0.7720
# [Epoch] 364  [Train] Loss: 0.7856, Accuracy: 0.7143 [Valid] Loss: 0.7398, Accuracy: 0.7720
# [Epoch] 365  [Train] Loss: 0.8942, Accuracy: 0.6500 [Valid] Loss: 0.7374, Accuracy: 0.7720
# [Epoch] 366  [Train] Loss: 0.7811, Accuracy: 0.6714 [Valid] Loss: 0.7351, Accuracy: 0.7740
# [Epoch] 367  [Train] Loss: 0.8449, Accuracy: 0.7071 [Valid] Loss: 0.7327, Accuracy: 0.7760
# [Epoch] 368  [Train] Loss: 0.9061, Accuracy: 0.6429 [Valid] Loss: 0.7315, Accuracy: 0.7780
# [Epoch] 369  [Train] Loss: 0.7464, Accuracy: 0.6929 [Valid] Loss: 0.7308, Accuracy: 0.7780
# [Epoch] 370  [Train] Loss: 0.8928, Accuracy: 0.6286 [Valid] Loss: 0.7290, Accuracy: 0.7780
# [Epoch] 371  [Train] Loss: 0.9591, Accuracy: 0.6429 [Valid] Loss: 0.7262, Accuracy: 0.7780
# [Epoch] 372  [Train] Loss: 0.9397, Accuracy: 0.6286 [Valid] Loss: 0.7247, Accuracy: 0.7800
# [Epoch] 373  [Train] Loss: 0.9385, Accuracy: 0.6286 [Valid] Loss: 0.7245, Accuracy: 0.7800
# [Epoch] 374  [Train] Loss: 0.8009, Accuracy: 0.7071 [Valid] Loss: 0.7249, Accuracy: 0.7820
# [Epoch] 375  [Train] Loss: 0.7901, Accuracy: 0.6714 [Valid] Loss: 0.7231, Accuracy: 0.7860
# [Epoch] 376  [Train] Loss: 0.7823, Accuracy: 0.6857 [Valid] Loss: 0.7205, Accuracy: 0.7840
# [Epoch] 377  [Train] Loss: 0.7200, Accuracy: 0.6929 [Valid] Loss: 0.7180, Accuracy: 0.7860
# [Epoch] 378  [Train] Loss: 0.8752, Accuracy: 0.6500 [Valid] Loss: 0.7157, Accuracy: 0.7860
# [Epoch] 379  [Train] Loss: 0.8275, Accuracy: 0.6714 [Valid] Loss: 0.7142, Accuracy: 0.7840
# [Epoch] 380  [Train] Loss: 0.7557, Accuracy: 0.6786 [Valid] Loss: 0.7128, Accuracy: 0.7860
# [Epoch] 381  [Train] Loss: 0.7535, Accuracy: 0.6929 [Valid] Loss: 0.7118, Accuracy: 0.7820
# [Epoch] 382  [Train] Loss: 0.9293, Accuracy: 0.6429 [Valid] Loss: 0.7094, Accuracy: 0.7800
# [Epoch] 383  [Train] Loss: 0.9007, Accuracy: 0.6214 [Valid] Loss: 0.7073, Accuracy: 0.7800
# [Epoch] 384  [Train] Loss: 0.9164, Accuracy: 0.6857 [Valid] Loss: 0.7054, Accuracy: 0.7780
# [Epoch] 385  [Train] Loss: 0.7142, Accuracy: 0.6786 [Valid] Loss: 0.7030, Accuracy: 0.7780
# [Epoch] 386  [Train] Loss: 0.8088, Accuracy: 0.6643 [Valid] Loss: 0.7012, Accuracy: 0.7820
# [Epoch] 387  [Train] Loss: 0.8713, Accuracy: 0.6571 [Valid] Loss: 0.7007, Accuracy: 0.7800
# [Epoch] 388  [Train] Loss: 0.8728, Accuracy: 0.6714 [Valid] Loss: 0.7010, Accuracy: 0.7760
# [Epoch] 389  [Train] Loss: 0.8668, Accuracy: 0.6429 [Valid] Loss: 0.7012, Accuracy: 0.7720
# [Epoch] 390  [Train] Loss: 0.8908, Accuracy: 0.6929 [Valid] Loss: 0.7021, Accuracy: 0.7720
# [Epoch] 391  [Train] Loss: 0.6588, Accuracy: 0.7214 [Valid] Loss: 0.7027, Accuracy: 0.7740
# [Epoch] 392  [Train] Loss: 0.8581, Accuracy: 0.7000 [Valid] Loss: 0.7041, Accuracy: 0.7700
# [Epoch] 393  [Train] Loss: 0.9959, Accuracy: 0.6143 [Valid] Loss: 0.7057, Accuracy: 0.7720
# [Epoch] 394  [Train] Loss: 0.7740, Accuracy: 0.6571 [Valid] Loss: 0.7076, Accuracy: 0.7700
# [Epoch] 395  [Train] Loss: 0.7923, Accuracy: 0.7214 [Valid] Loss: 0.7093, Accuracy: 0.7760
# [Epoch] 396  [Train] Loss: 0.8834, Accuracy: 0.6286 [Valid] Loss: 0.7113, Accuracy: 0.7740
# [Epoch] 397  [Train] Loss: 0.8394, Accuracy: 0.7000 [Valid] Loss: 0.7119, Accuracy: 0.7740
# [Epoch] 398  [Train] Loss: 0.7461, Accuracy: 0.7000 [Valid] Loss: 0.7133, Accuracy: 0.7760
# [Epoch] 399  [Train] Loss: 0.7539, Accuracy: 0.7071 [Valid] Loss: 0.7151, Accuracy: 0.7760
# [Epoch] 400  [Train] Loss: 0.9503, Accuracy: 0.6357 [Valid] Loss: 0.7157, Accuracy: 0.7760
# [Epoch] 401  [Train] Loss: 0.8785, Accuracy: 0.6786 [Valid] Loss: 0.7148, Accuracy: 0.7780
# [Epoch] 402  [Train] Loss: 0.7172, Accuracy: 0.7143 [Valid] Loss: 0.7137, Accuracy: 0.7780
# [Epoch] 403  [Train] Loss: 0.8836, Accuracy: 0.6500 [Valid] Loss: 0.7125, Accuracy: 0.7780
# [Epoch] 404  [Train] Loss: 0.8111, Accuracy: 0.6643 [Valid] Loss: 0.7120, Accuracy: 0.7780
# [Epoch] 405  [Train] Loss: 0.7869, Accuracy: 0.6643 [Valid] Loss: 0.7128, Accuracy: 0.7780
# [Epoch] 406  [Train] Loss: 0.7567, Accuracy: 0.7000 [Valid] Loss: 0.7145, Accuracy: 0.7820
# [Epoch] 407  [Train] Loss: 0.7673, Accuracy: 0.6643 [Valid] Loss: 0.7162, Accuracy: 0.7800
# [Epoch] 408  [Train] Loss: 0.6521, Accuracy: 0.7429 [Valid] Loss: 0.7188, Accuracy: 0.7780
# [Epoch] 409  [Train] Loss: 0.8581, Accuracy: 0.6786 [Valid] Loss: 0.7227, Accuracy: 0.7740
# [Epoch] 410  [Train] Loss: 0.9451, Accuracy: 0.6643 [Valid] Loss: 0.7244, Accuracy: 0.7780
# [Epoch] 411  [Train] Loss: 0.7909, Accuracy: 0.6500 [Valid] Loss: 0.7244, Accuracy: 0.7820
# [Epoch] 412  [Train] Loss: 0.8967, Accuracy: 0.6571 [Valid] Loss: 0.7224, Accuracy: 0.7860
# [Epoch] 413  [Train] Loss: 0.7174, Accuracy: 0.6857 [Valid] Loss: 0.7213, Accuracy: 0.7840
# [Epoch] 414  [Train] Loss: 0.8028, Accuracy: 0.6643 [Valid] Loss: 0.7205, Accuracy: 0.7880
# Optimization Finished!
# Loading 214th model
#
# [Test] Loss: 0.6768, Accuracy: 0.7900
